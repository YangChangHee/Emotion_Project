# %% [markdown]
# # It is not good to apply to general images

# %%
import face_alignment
from skimage import io

# %%
import numpy as np
input_data=np.load("CK+dataset.npy")
label=np.load("CK+label.npy")

# %%
fa = face_alignment.FaceAlignment(face_alignment.LandmarksType._2D, device='cuda')

input = input_data[1]*255
preds = fa.get_landmarks(input)

# %%
x=[]
y=[]
for i in range(len(preds[0])):
    x.append(preds[0][i][0])
    y.append(preds[0][i][1])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
img= input_data[1]*255
img=np.array(img,dtype=np.uint8)

# %%
import cv2
for j in range(68):
    cv2.putText(img,str(j),(x[j],y[j]),cv2.FONT_HERSHEY_SCRIPT_SIMPLEX,0.1,(0,255,0))

# %%
plt.imshow(img)
