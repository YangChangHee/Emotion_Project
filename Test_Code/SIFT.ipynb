# %% [markdown]
# # SIFT

# %% [markdown]
# # Image Load

# %%
import cv2
img='/home/lab/양창희/Emotion Project/Test_image/test_1.jpg'

# %%
img=cv2.imread(img)

# %% [markdown]
# # CLOCKWISE 90

# %%
img90 = cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)

# %%
img.shape,img90.shape
# Out:
# ((252, 200, 3), (200, 252, 3))

# %%
import matplotlib.pyplot as plt
rows=1
cols=2
fig=plt.figure()
ax1=fig.add_subplot(rows,cols,1)
ax1.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
ax1.axis("off")

ax2=fig.add_subplot(rows,cols,2)
ax2.imshow(cv2.cvtColor(img90, cv2.COLOR_BGR2RGB))
ax2.axis("off")
plt.show()

# %% [markdown]
# # Gray Transform

# %%
imgray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
imgray90=cv2.cvtColor(img90,cv2.COLOR_BGR2GRAY)

# %%
imgray.shape
# Out:
# (252, 200)

# %%
rows=1
cols=2
fig=plt.figure()
ax1=fig.add_subplot(rows,cols,1)
ax1.imshow(imgray, cmap='gray')
ax1.axis("off")

ax2=fig.add_subplot(rows,cols,2)
ax2.imshow(imgray90, cmap='gray')
ax2.axis("off")
plt.show()

# %% [markdown]
# # OpenCv SIFT Function Load

# %%
img2, img3 = None,None
sift = cv2.xfeatures2d.SIFT_create()

# %% [markdown]
# # Keypoin Descriptor

# %%
kp1, desc1 = sift.detectAndCompute(imgray, None)
kp2, desc2 = sift.detectAndCompute(imgray90, None)

# %%
img2 = cv2.drawKeypoints(imgray, kp1, img2)
img3 = cv2.drawKeypoints(imgray90, kp2, img3)

# %% [markdown]
# # Keypoint Draw

# %%
rows=1
cols=2
fig=plt.figure()
ax1=fig.add_subplot(rows,cols,1)
ax1.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
ax1.axis("off")

ax2=fig.add_subplot(rows,cols,2)
ax2.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
ax2.axis("off")
plt.show()

# %%
img4, img5 = None,None
img4 = cv2.drawKeypoints(imgray, kp1, img4,
                        flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
img5 = cv2.drawKeypoints(imgray90, kp2, img5,
                        flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %% [markdown]
# # Keypoint and Flag Draw

# %%
rows=1
cols=2
fig=plt.figure()
ax1=fig.add_subplot(rows,cols,1)
ax1.imshow(cv2.cvtColor(img4, cv2.COLOR_BGR2RGB))
ax1.axis("off")

ax2=fig.add_subplot(rows,cols,2)
ax2.imshow(cv2.cvtColor(img5, cv2.COLOR_BGR2RGB))
ax2.axis("off")
plt.show()

# %% [markdown]
# # Image Matching

# %%
matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

# %%
matches = matcher.match(desc1, desc2)

# %%
res = cv2.drawMatches(img, kp1, img90, kp2, matches, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

# %%
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))

# %%
import os
def draw_2_image(image,image2):
    rows=1
    cols=2
    fig=plt.figure()
    ax1=fig.add_subplot(rows,cols,1)
    ax1.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    ax1.axis("off")

    ax2=fig.add_subplot(rows,cols,2)
    ax2.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
    ax2.axis("off")
    plt.show()

# %%
def draw_2_gray_image(image,image2):
    rows=1
    cols=2
    fig=plt.figure()
    ax1=fig.add_subplot(rows,cols,1)
    ax1.imshow(image, cmap='gray')
    ax1.axis("off")

    ax2=fig.add_subplot(rows,cols,2)
    ax2.imshow(image2, cmap='gray')
    ax2.axis("off")
    plt.show()

# %%
def SIFT_Draw_Image(image):
    img=image
    img90 = cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
    draw_2_image(img,img90)
    
    imgray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    imgray90=cv2.cvtColor(img90,cv2.COLOR_BGR2GRAY)
    draw_2_gray_image(imgray,imgray90)
    
    img2, img3 = None,None
    sift = cv2.xfeatures2d.SIFT_create()
    kp1, desc1 = sift.detectAndCompute(imgray, None)
    kp2, desc2 = sift.detectAndCompute(imgray90, None)
    img2 = cv2.drawKeypoints(imgray, kp1, img2)
    img3 = cv2.drawKeypoints(imgray90, kp2, img3)
    draw_2_image(img2,img3)
    
    img4, img5 = None,None
    img4 = cv2.drawKeypoints(imgray, kp1, img4,
                            flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    img5 = cv2.drawKeypoints(imgray90, kp2, img5,
                            flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    draw_2_image(img4,img5)
    
    matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
    matches = matcher.match(desc1, desc2)
    res = cv2.drawMatches(img, kp1, img90, kp2, matches, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
    plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))

# %%
def SIFT(image):
    img=image
    img90 = cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
    
    imgray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    imgray90=cv2.cvtColor(img90,cv2.COLOR_BGR2GRAY)
    
    img2, img3 = None,None
    sift = cv2.xfeatures2d.SIFT_create()
    kp1, desc1 = sift.detectAndCompute(imgray, None)
    kp2, desc2 = sift.detectAndCompute(imgray90, None)
    img2 = cv2.drawKeypoints(imgray, kp1, img2)
    img3 = cv2.drawKeypoints(imgray90, kp2, img3)
    
    img4, img5 = None,None
    img4 = cv2.drawKeypoints(imgray, kp1, img4,
                            flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    img5 = cv2.drawKeypoints(imgray90, kp2, img5,
                            flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    
    matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
    matches = matcher.match(desc1, desc2)
    res = cv2.drawMatches(img, kp1, img90, kp2, matches, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
    plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))

# %%
img='/home/lab/양창희/Emotion Project/Test_image/test_2.jpg'
img=cv2.imread(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
SIFT_Draw_Image(img)

# %%
SIFT(img)
