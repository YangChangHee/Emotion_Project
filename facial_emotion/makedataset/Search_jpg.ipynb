# %%
import os
result=[]
def search(dirname):
    try:
        filenames = os.listdir(dirname)
        for filename in filenames:
            full_filename = os.path.join(dirname, filename)
            if os.path.isdir(full_filename):
                search(full_filename)
            else:
                ext = os.path.splitext(full_filename)[-1]
                if ext == '.jpg': 
                    print(full_filename)
                    result.append(full_filename)
    except PermissionError:
        pass

search("/home/lab/dataset/facial_emotion_recognition/images/validation/surprise")
# Out:
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/24893.jpg
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/18555.jpg
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/20407.jpg
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/32510.jpg
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/14375.jpg
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/28342.jpg
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/32979.jpg
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/32734.jpg
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/15944.jpg
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/9776.jpg
# /home/lab/dataset/facial_emotion_recognition/images/validation/surprise/5530.jpg
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm, tqdm_notebook
from tqdm import trange
import time
surprise=[]
for i in tqdm(range(len(result))):
    time.sleep(0.000000000001)
    img=cv2.imread(result[i])
    surprise.append(img)
import numpy as np
surprise=np.array(surprise)
# Out:
# 100%|██████████| 797/797 [00:00<00:00, 4392.56it/s]

# %%
angry.shape
# Out:
# (960, 48, 48, 3)

# %%
np.save('/home/lab/양창희/Emotion Project/emotion_image_npy/validation_img_surprise.npy',surprise)
